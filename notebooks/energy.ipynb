# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt
from scipy import signal

import os
from scipy.interpolate import griddata

# %%
os.chdir('/home/jiarong/research/')
# Usage of energy plot functions
# The default is only plot the total + dissipation energy and smoothing is not turned on    
# The growth rate curve needs smoothing but probably should be recomputed
# label_set = ['U* = 1', 'U* = 0.8', 'U* = 0.7', 'U* = 0.6']
from energy_func import energy_comparison
# Creating 2 subplots
fig = plt.figure(figsize = (15, 5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
# List here that cases that needs to be compared and there distinct labels

filename_set = ['./07.04/parameter/'+'linear_m5B0Ustar0.45ak0.05Bo3.45Re31000./'+'budgetWaterwind.dat']
label_set = ['U* = 0.45, ak = 0.05, RE = 31000']
# energy = pd.read_table(filename_set[0], delimiter = ' ', error_bad_lines=False)
growth_rate_set = energy_comparison(filename_set, label_set, ax1, ax2, smooth = 'YES', simp = 'YES')

filename_set = ['./05.28/'+'linear_m5B0Ustar0.51ak0.05Bo3.45Re31000./'+'budgetWaterwind.dat']
label_set = ['U* = 0.50, ak = 0,05, RE = 31000']  # which should be 0.51
growth_rate_set = energy_comparison(filename_set, label_set, ax1, ax2, smooth = 'YES', simp = 'YES')

filename_set = ['./07.04/parameter/'+'linear_m5B0Ustar0.55ak0.05Bo3.45Re31000./'+'budgetWaterwind.dat']
label_set = ['U* = 0.55, ak = 0.05, RE = 31000']
growth_rate_set = energy_comparison(filename_set, label_set, ax1, ax2, smooth = 'YES', simp = 'YES')


ax1.legend()
ax2.legend()
# Might want to change this
ax1.set_xlim([0, 40])
ax1.set_ylim([0.9, 40])
ax2.set_xlim([0, 40])
ax2.set_ylim([-0.1, 0.4])
plt.show()

# %%
from energy_func import energy_comparison
# Creating 2 subplots
fig = plt.figure(figsize = (15, 5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

filename_set = ['./07.04/parameter/'+'linear_m5B0Ustar0.45ak0.05Bo3.45Re31000./'+'budgetWaterwind.dat']
label_set = ['U* = 0.45, ak = 0.05, RE = 31000']
growth_rate_set = energy_comparison(filename_set, label_set, ax1, ax2, smooth = 'YES', simp = 'YES')

filename_set = ['./07.04/parameter/'+'linear_m5B0Ustar0.45ak0.1Bo3.45Re31000./'+'budgetWaterwind.dat']
label_set = ['U* = 0.45, ak = 0.1, RE = 31000']
growth_rate_set = energy_comparison(filename_set, label_set, ax1, ax2, smooth = 'YES', simp = 'YES')

filename_set = ['./07.04/parameter/'+'linear_m5B0Ustar0.55ak0.05Bo3.45Re31000./'+'budgetWaterwind.dat']
label_set = ['U* = 0.55, ak = 0.05, RE = 31000']
growth_rate_set = energy_comparison(filename_set, label_set, ax1, ax2, smooth = 'YES', simp = 'YES')

filename_set = ['./07.04/parameter/'+'linear_m5B0Ustar0.55ak0.1Bo3.45Re31000./'+'budgetWaterwind.dat']
label_set = ['U* = 0.55, ak = 0.1']
growth_rate_set = energy_comparison(filename_set, label_set, ax1, ax2, smooth = 'YES', simp = 'YES')

ax1.legend()
ax2.legend()
# Might want to change this
ax1.set_xlim([0, 40])
ax1.set_ylim([0.9, 40])
ax2.set_xlim([0, 40])
ax2.set_ylim([-0.1, 0.4])
plt.show()

# %%
from energy_func import energy_comparison
# Creating 2 subplots
fig = plt.figure(figsize = (15, 5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

filename_set = ['./05.28/'+'linear_m5B0Ustar0.51ak0.05Bo3.45Re31000./'+'budgetWaterwind.dat']
label_set = ['U* = 0.50, ak = 0,05, RE = 31000']  # which should be 0.51
growth_rate_set = energy_comparison(filename_set, label_set, ax1, ax2, smooth = 'YES', simp = 'YES')

filename_set = ['./07.04/parameter/'+'linear_m5B0Ustar0.5ak0.05Bo3.45Re10000./'+'budgetWaterwind.dat']
label_set = ['U* = 0.50, ak = 0.05, RE = 10000']
growth_rate_set = energy_comparison(filename_set, label_set, ax1, ax2, smooth = 'YES', simp = 'YES')

ax1.legend()
ax2.legend()
# Might want to change this
ax1.set_xlim([0, 40])
ax1.set_ylim([0.9, 40])
ax2.set_xlim([0, 40])
ax2.set_ylim([-0.1, 0.4])
plt.show()
