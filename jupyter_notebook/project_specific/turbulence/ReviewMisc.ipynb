# %% [markdown]
# ### This notebook makes miscellaneous plots used during the review process

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import pandas as pd
import matplotlib as mpl
plt.style.use('/projects/DEIKE/jiarongw/jiarongw-postprocessing/media/matplotlib/stylelib/jfm.mplstyle')
import matplotlib.image as mpimg

# %%
fig = plt.figure(figsize=[2,2]); ax = plt.gca()
path = './review/'
# img = mpimg.imread(path+'growth2_1.png')
img = mpimg.imread(path+'mesh.png')
pcontour = ax.imshow(img, extent=[-np.pi,np.pi,-1,2*np.pi-1], vmax=1, vmin=-1, cmap='coolwarm', alpha=1)
x = np.linspace(-np.pi,np.pi,512)
eta = (0.05/4)*np.cos(4*x-0.7)
plt.plot(x, eta, c='r',lw=0.5)
plt.axis('off')
fig.savefig('./review/mesh.pdf', bbox_inches='tight')

# %%
fig = plt.figure(figsize=[2,2]); ax = plt.gca()
path = './review/'

img = mpimg.imread(path+'mesh_ak0.25.tiff')
pcontour = ax.imshow(img, extent=[-np.pi,np.pi,-1,2*np.pi-1], vmax=40, vmin=-20, cmap='jet', alpha=1)

# from defs import Case, Interface2D
# case = Case(ustar=0.25, Retau=720, Bo=200, g=1, ak=0.25, LEVEL=10, emax=0.3, alterMU=16, NOMATCH=True, 
#             PRINTWAVE=True, OUTLEVEL=9, working_dir='/projects/DEIKE/jiarongw/turbulence/', prefix='curved_fixREtau_boundary_')
# interface = Interface2D(L0 = case.L0, N = case.N, 
#                         path = case.path, pre='eta/eta_loc_t', t=59.5, PRUNING=True, pruningz=case.h+0.4/case.k) 

x = np.linspace(-np.pi,np.pi,512)
eta = (np.average(interface.eta, axis=0)-np.average(interface.eta))
ax.plot(x, eta, c='r',lw=0.5)

cax1 = fig.add_axes([0.94, 0.2, 0.03, 0.5])
cbar1 = fig.colorbar(pcontour, orientation="vertical", cax=cax1)
cax1.text(0.5, 1.1, r'$u/u_{*}$', ha='center', va='center', transform=cax1.transAxes)
cbar1.set_ticks([-20, 0, 20, 40])
ax.axis('off')
fig.savefig('./review/mesh_ak0.25.pdf', bbox_inches='tight')
